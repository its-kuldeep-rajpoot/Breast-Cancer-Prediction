# %% [markdown]
# Pre-information about data:
#
# 1= Malignant (Cancerous) - Present
# 0= Benign (Not Cancerous) -Absent

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("breast_cancer_data.csv")

# %%
data.shape
# Out:
# (569, 33)

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
new_df = data.drop(["id",'Column1'], axis=1)

# %%
new_df.shape
# Out:
# (569, 31)

# %%
new_df.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
new_df.replace({'diagnosis':{"M":1,"B":0}}, inplace=True)

# %%
new_df.diagnosis.value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
new_df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ## Model building:

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
X = new_df.drop(['diagnosis'], axis=1)
y = new_df['diagnosis']

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

for i in X.columns:
    X[i+' Normalized'] = scaler.fit_transform(X[i].values.reshape(-1, 1))
    X.drop([i], inplace= True, axis= 1)

# %%
X.head()
# Out:
#    radius_mean Normalized  texture_mean Normalized  perimeter_mean Normalized  \
# 0                1.097064                -2.073335                   1.269934
# 1                1.829821                -0.353632                   1.685955
# 2                1.579888                 0.456187                   1.566503
# 3               -0.768909                 0.253732                  -0.592687
# 4                1.750297                -1.151816                   1.776573
#
#    area_mean Normalized  smoothness_mean Normalized  \
# 0              0.984375                    1.568466
# 1              1.908708                   -0.826962
# 2              1.558884                    0.942210
# 3             -0.764464                    3.283553
# 4              1.826229                    0.280372
#
#    compactness_mean Normalized  concavity_mean Normalized  \
# 0                     3.283515                   2.652874
# 1                    -0.487072                  -0.023846
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.15, stratify=y, random_state=1)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (483, 30) (86, 30) (483,) (86,)

# %%
lr_model = LogisticRegression(max_iter=34, random_state=1)

lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=34, random_state=1)

# %%
y_pred = lr_model.predict(X_test)

# %%
acc = accuracy_score(y_pred, y_test)
print("Accuracy : ", acc)
# Out:
# Accuracy :  0.9767441860465116

# %%
c = classification_report(y_test, y_pred)
print(c)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        54
#            1       0.97      0.97      0.97        32
#
#     accuracy                           0.98        86
#    macro avg       0.98      0.98      0.98        86
# weighted avg       0.98      0.98      0.98        86
